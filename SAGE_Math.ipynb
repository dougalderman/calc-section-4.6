# %%
x = var('x')

# %%
def f(x): return x^5*ln(x)

# %%
p = []

# %%
p.append(plot(f(x),(x,0,1), color='blue'))

# %%
p.append(plot(f(x),(x,1,10), fill=true, color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,10,11), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, 1, 10)

# %%
int
# Out:
# 500000/3*log(10) - 111111/4

# %%
numerical_approx(int)
# Out:
# 355986.432165674
